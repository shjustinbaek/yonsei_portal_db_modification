# %%
import pandas as pd
import numpy as np

# %%
SUBJECT = pd.read_csv("SUBJECT.csv",encoding='utf-8')
mileage = pd.read_csv("C:/Users/naval/Desktop/Gits/YonseiMileage/data.csv",encoding='ms949')
# Out:
# C:\Users\naval\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mileage.head(2)
# Out:
#      연도  학기 구분1          구분2 구분3     학정번호-분반-실습    과목명   학점 담당교수 강의시간 ...  \
# 0  2019   1  학부  교양기초(2019~)  채플  YCA1001-01-00  채플(1)  0.0  곽호철   화2 ...
# 1  2019   1  학부  교양기초(2019~)  채플  YCA1001-01-00  채플(1)  0.0  곽호철   화2 ...
#
#   마일리지  전공자/복수전공자(전공자정원포함여부)  신청과목수 졸업신청  초수강여부  총이수학점/졸업이수학점  \
# 0    2                 Y (Y)      6    N      Y        0.4603
# 1    2                 Y (Y)      5    Y      Y        0.8730
#
#    직전학기이수학점/학기당수강학점  학년 수강여부  비고
# 0            0.8421   3    O
# 1            0.8333   4    O
#
# [2 rows x 34 columns]

# %%
temp = mileage[['연도','학기','구분1','구분2','구분3','학정번호-분반-실습','마일리지','수강여부']]

# %%
subject_names
# Out:
# {'2019_1학기_학부_공통기초(10~18)_글쓰기_YCB1101-63-00',
#  '2019_1학기_학부_언더우드국제대학_공통교과과정(신촌)_UIC3558-01-00',
#  '2019_2학기_학부_학부선택(~2009)_건강과스포츠_UCL1101-03-00',
#  '2019_2학기_학부_언더우드국제대학_공통교과과정(국제)_PHY1002-08-02',
#  '2019_2학기_학부_필수교양(10~18)_언어와표현_YCF1603-01-00',
#  '2019_2학기_학부_공과대학_공과대학공통_ENG2005-01-00',
#  '2019_2학기_학부_필수교양(10~18)_언어와표현_YCF1410-01-00',
#  '2019_1학기_학부_생명시스템대학_시스템생물학전공_BIO3107-01-00',
#  '2019_1학기_학부_교육과학대학_교육학전공_EDU2125-01-00',
#  '2019_2학기_학부_공과대학_기계공학전공_MEU3680-03-00',
#  '2019_2학기_학부_문과대학_노어노문학전공_RUS2106-02-00',
#  '2019_1학기_학부_생명시스템대학_생화학전공_BCH4112-01-00',
#  '2019_2학기_학부_공과대학_건축학(설계)_ARC4305-01-00',
#  '2019_1학기_학부_학부선택(~2009)_문학과예술_UCJ1131-01-00',
#  '2019_2학기_학부_학부선택(~2009)_인간이해와역사_UCG1125-01-00',
#  '2019_1학기_학부_대학교양(2019~)_문학과예술_UCE1105-02-00',
#  '2019_1학기_학부_약학대학_약학전공_PHM3005-01-00',
#  '2019_2학기_학부_경영대학_경영학전공_BIZ1101-01-00',
#  '2019_1학기_학부_사회과학대학_정치외교학전공_POL4833-01-00',
#  '2019_2학기_학부_학부기초(~2009)_대학영어_YCC1001-04-00',
# ...

# %%
def hak(x):
    return str(x)+'학기'
temp['학기'] = temp['학기'].apply(hak)
# Out:
# C:\Users\naval\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
temp.columns = ['OpenYear', 'OpenSem', 'G1','G2', 'G3', 'SubjectID', 'MileageBet', 'IfEnrolled']

# %%
subject_names = []
for item in SUBJECT.values:
    subject_names.append('_'.join(map(str, item[:6])).strip())
subject_names = set(subject_names)


# raw_SUBJECT_PROFESSOR.columns = ['OpenYear', 'OpenSem', 'G1', 'G2', 'G3', 'SubjectID', 'BuildingName']
check = []
for item in temp[['OpenYear', 'OpenSem', 'G1', 'G2', 'G3', 'SubjectID']].values:
    name = '_'.join(map(str, item)).strip()
    if name in subject_names:
        check.append(1)
    else:
        check.append(0)

temp['check'] = check
print(temp['check'].value_counts())
temp = temp[temp['check'] == 1]
# Out:
# 0    473671
# 1    131883
# Name: check, dtype: int64
# C:\Users\naval\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
del temp['check']

# %%
del temp['G1']

# %%
temp.columns = ['SUBJECT_OpenYear', 'SUBJECT_OpenSem', 'SUBJECT_G2', 'SUBJECT_G3', 'SUBJECT_SubjectID', 'MileageBet','IfEnrolled']

# %%
temp
# Out:
#         SUBJECT_OpenYear SUBJECT_OpenSem   SUBJECT_G2        SUBJECT_G3  \
# 0                   2019             1학기  교양기초(2019~)                채플
# 1                   2019             1학기  교양기초(2019~)                채플
# 2                   2019             1학기  교양기초(2019~)                채플
# 3                   2019             1학기  교양기초(2019~)                채플
# 4                   2019             1학기  교양기초(2019~)                채플
# 5                   2019             1학기  교양기초(2019~)                채플
# 6                   2019             1학기  교양기초(2019~)                채플
# 7                   2019             1학기  교양기초(2019~)                채플
# 8                   2019             1학기  교양기초(2019~)                채플
# 9                   2019             1학기  교양기초(2019~)                채플
# 10                  2019             1학기  교양기초(2019~)                채플
# 11                  2019             1학기  교양기초(2019~)                채플
# ...

# %% [markdown]
# ### StudentID allocation

# %%
students = pd.read_csv("STUDENT.csv",encoding='utf-8')

# %%
# Out:
# array([29, 85, 48, ..., 66, 77, 52])

# %%
seq = [students.loc[i][0] for i in np.random.randint(low=1,high=90, size=131883)]

# %%
temp['StudentID'] = seq
# Out:
# C:\Users\naval\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
temp.to_csv("APPLIEDSUBJECT.csv",encoding='utf-8',index=False)
