# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import font_manager, rc
from matplotlib import style
import seaborn as sns
import random

# %%
font_name = font_manager.FontProperties(fname="C:/Users/naval/Desktop/KBIZ한마음고딕 M.ttf").get_name()

# %%
mpl.rcParams['axes.unicode_minus'] = False #그래프에서 - 폰트 깨지는거 방지
font_name = font_manager.FontProperties(fname="C:/Users/naval/Desktop/KBIZ한마음고딕 M.ttf").get_name()
rc('font', family=font_name)

# %%
df = pd.read_csv("sample.csv",encoding='ms949')

# %%
df
# Out:
#      Unnamed: 0  마일리지  전공자/복수전공자(전공자정원포함여부)  신청과목수   졸업신청  초수강여부  \
# 0         14058    36                 False      6  False   True
# 1         14059    36                 False      6   True   True
# 2         14060    36                 False      6   True   True
# 3         14061    36                 False      6   True   True
# 4         14062    36                 False      6   True  False
# 5         14063    36                 False      6  False   True
# 6         14064    36                 False      6  False   True
# 7         14065    36                 False      6  False   True
# 8         14066    36                 False      6  False   True
# 9         14067    36                 False      6  False   True
# 10        14068    36                 False      6  False   True
# 11        14069    36                 False      6  False   True
# 12        14070    36                 False      6  False   True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 15 columns):
# Unnamed: 0              171 non-null int64
# 마일리지                    171 non-null int64
# 전공자/복수전공자(전공자정원포함여부)    171 non-null bool
# 신청과목수                   171 non-null int64
# 졸업신청                    171 non-null bool
# 초수강여부                   171 non-null bool
# 총이수학점/졸업이수학점            171 non-null float64
# 직전학기이수학점/학기당수강학점        171 non-null float64
# 학년                      171 non-null int64
# 수강여부                    171 non-null bool
# 연도                      171 non-null int64
# 학기                      171 non-null int64
# 학정번호-분반-실습              171 non-null object
# 비고                      171 non-null object
# count                   171 non-null int64
# dtypes: bool(4), float64(2), int64(7), object(2)
# memory usage: 15.4+ KB

# %%
catplot1 = sns.catplot(x="학년", y="마일리지", hue = "수강여부", kind="swarm", data=df);
# Out:
# C:\Users\naval\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1241: UserWarning: findfont: Font family ['KBIZgo M'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Plotting hist without kde
succ = df[df['수강여부']==True]
fail = df[df['수강여부']==False]
#sns.set_style("whitegrid")
sns.distplot(succ['마일리지'], kde=False,color='skyblue')
sns.distplot(fail['마일리지'], kde=False, color='red')
#Removing Y ticks from the second axis

# %%
# Plotting hist without kde
ax = sns.distplot(df['마일리지'], kde=False,color='r')
# Creating another Y axis
second_ax = ax.twinx()
#Plotting kde without hist on the second Y axis
sns.distplot(df['마일리지'], ax=second_ax, kde=True, hist=False,color='r')
#Removing Y ticks from the second axis
second_ax.set_yticks([])

# %%
sns.lmplot(data=df, x='학년', y='마일리지', hue='수강여부',fit_reg=False)

# %%
#def ox_by_year(data):
temp_data = data[['학년','마일리지','수강여부']]
data_1st_year = temp_data[temp_data['학년']==1]
data_2nd_year = temp_data[temp_data['학년']==2]
data_3rd_year = temp_data[temp_data['학년']==3]
data_4rd_year = temp_data[temp_data['학년']==4]

# %%
sns.countplot(x = '마일리지',hue="학년",data=data)

# %%
nrow = 2
fig, ax = plt.subplots(2, 2, figsize=(30, 30))

sns.distplot(data_1st_year[''], label='1학년', ax=subplot)

for variable, subplot in zip(numeric_column, ax.flatten()):
    for k in data['Dx'].unique():
        sns.distplot(data[variable][data[variable].notnull()][data.Dx==k], label=k, ax=subplot)
    subplot.legend()

# %%
###빠른 seaborn 튜토리얼
